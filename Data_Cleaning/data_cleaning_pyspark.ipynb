# %% [markdown]
# #Overview
#
# Here we use PySpark to process the dataset. PySpark can be helpful to process huge datasets. Here is a brief description of the steps: <br><br>
#
# 1. First import the text file into a PySpark dataframe
# 2. Split the dataframe into two columns one for the English sentences and the second for the German sentences
# 3. Define an UDF with steps described above to clean up each columns
# 4. Save the dataframe into a CSV file

# %% [markdown]
# # Libraries

# %%
import re
import string 
import pandas as pd 
from unicodedata import normalize
from pyspark.sql.functions import regexp_extract, lower
import pyspark.sql.functions as F
from pyspark.sql.functions import *

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=1587606511088271#setting/sparkui/0619-220129-mekvy8s7/driver-1020714604257599109">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sqlContext
# Out:
# Out[113]: <pyspark.sql.context.SQLContext at 0x7f3544068370>

# %%
# Shows a dict of PySpark informations. We can check if 'sc', 'sqlContext', and 'spark' are present.
# locals()

# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=1587606511088271#setting/sparkui/0619-220129-mekvy8s7/driver-1020714604257599109">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %% [markdown]
# # Import Data

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Bookings.csv</td><td>Bookings.csv</td><td>170118</td><td>1674344235000</td></tr><tr><td>dbfs:/FileStore/tables/English-German.csv/</td><td>English-German.csv/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Facilities.csv</td><td>Facilities.csv</td><td>494</td><td>1674344235000</td></tr><tr><td>dbfs:/FileStore/tables/Members.csv</td><td>Members.csv</td><td>3313</td><td>1674344236000</td></tr><tr><td>dbfs:/FileStore/tables/NASA_access_log_Aug95.txt</td><td>NASA_access_log_Aug95.txt</td><td>167813770</td><td>1675580793000</td></tr><tr><td>dbfs:/FileStore/tables/NASA_access_log_Jul95.txt</td><td>NASA_access_log_Jul95.txt</td><td>205242368</td><td>1675580851000</td></tr><tr><td>dbfs:/FileStore/tables/deu.txt</td><td>deu.txt</td><td>40721427</td><td>1687189983000</td></tr></tbody></table></div>

# %%
# File location and type
file_location = "dbfs:/FileStore/tables/deu.txt"
file_type = "txt"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
# df = spark.read.format(file_type) \
#   .option("inferSchema", infer_schema) \
#   .option("header", first_row_is_header) \
#   .option("sep", delimiter) \
#   .load(file_location)

# df = spark.read.text('dbfs:/FileStore/tables/deu.txt')
df = spark.read.text(file_location)

# display(df) # display is too long on github use show instead
df.show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |Go.\tGeh.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)                      |
# |Hi.\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)                    |
# |Hi.\tGrüß Gott!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)          |
# |Run!\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)             |
# |Run.\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)           |
# |Wow!\tPotzdonner!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122382 (Pfirsichbaeumchen)  |
# |Wow!\tDonnerwetter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122391 (Pfirsichbaeumchen)|
# |Duck!\tKopf runter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #280158 (CM) & #9968521 (wolfgangth)         |
# |Fire!\tFeuer!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1958697 (Tamy)              |
# |Help!\tHilfe!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #575889 (MUIRIEL)             |
# +--------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
df.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
df.head(3)
# Out:
# Out[118]: [Row(value='Go.\tGeh.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'),
#  Row(value='Hi.\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'),
#  Row(value='Hi.\tGrüß Gott!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)')]

# %%
type(df)
# Out:
# Out[119]: pyspark.sql.dataframe.DataFrame

# %%
df_rdd = df.rdd
type(df_rdd)
# Out:
# Out[120]: pyspark.rdd.RDD

# %%
df_rdd.take(5)
# Out:
# Out[121]: [Row(value='Go.\tGeh.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'),
#  Row(value='Hi.\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'),
#  Row(value='Hi.\tGrüß Gott!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)'),
#  Row(value='Run!\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)'),
#  Row(value='Run.\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)')]

# %%
df.show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------+
# |value                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------+
# |Go.\tGeh.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)                      |
# |Hi.\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)                    |
# |Hi.\tGrüß Gott!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)          |
# |Run!\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)             |
# |Run.\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)           |
# |Wow!\tPotzdonner!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122382 (Pfirsichbaeumchen)  |
# |Wow!\tDonnerwetter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122391 (Pfirsichbaeumchen)|
# |Duck!\tKopf runter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #280158 (CM) & #9968521 (wolfgangth)         |
# |Fire!\tFeuer!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1958697 (Tamy)              |
# |Help!\tHilfe!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #575889 (MUIRIEL)             |
# +--------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
df_rdd.take(10)
# Out:
# Out[123]: [Row(value='Go.\tGeh.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)'),
#  Row(value='Hi.\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)'),
#  Row(value='Hi.\tGrüß Gott!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)'),
#  Row(value='Run!\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)'),
#  Row(value='Run.\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)'),
#  Row(value='Wow!\tPotzdonner!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122382 (Pfirsichbaeumchen)'),
#  Row(value='Wow!\tDonnerwetter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122391 (Pfirsichbaeumchen)'),
#  Row(value='Duck!\tKopf runter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #280158 (CM) & #9968521 (wolfgangth)'),
#  Row(value='Fire!\tFeuer!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1958697 (Tamy)'),
#  Row(value='Help!\tHilfe!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #575889 (MUIRIEL)')]

# %%
print(df.count(), len(df.columns))
# Out:
# 261499 1

# %% [markdown]
# # Process Data

# %%
sample_sentences = [item['value'] for item in df.take(100)]
sample_sentences
# Out:
# Out[125]: ['Go.\tGeh.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8597805 (Roujin)',
#  'Hi.\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #380701 (cburgmer)',
#  'Hi.\tGrüß Gott!\tCC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #659813 (Esperantostern)',
#  'Run!\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #941078 (Fingerhut)',
#  'Run.\tLauf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #941078 (Fingerhut)',
#  'Wow!\tPotzdonner!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122382 (Pfirsichbaeumchen)',
#  'Wow!\tDonnerwetter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #2122391 (Pfirsichbaeumchen)',
#  'Duck!\tKopf runter!\tCC-BY 2.0 (France) Attribution: tatoeba.org #280158 (CM) & #9968521 (wolfgangth)',
#  'Fire!\tFeuer!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1958697 (Tamy)',
#  'Help!\tHilfe!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #575889 (MUIRIEL)',
#  'Help!\tZu Hülf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #2122375 (Pfirsichbaeumchen)',
#  'Stay.\tBleib!\tCC-BY 2.0 (France) Attribution: tatoeba.org #8907595 (CK) & #5344007 (wochenweise)',
#  'Stop!\tStopp!\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (CM) & #626467 (jakov)',
#  'Stop!\tAnhalten!\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (CM) & #7481623 (Yorwba)',
#  'Wait!\tWarte!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #2122378 (Pfirsichbaeumchen)',
#  'Wait.\tWarte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #8597806 (Roujin)',
#  'Begin.\tFang an.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6102432 (mailohilohi) & #4942826 (Hans_Adler)',
#  'Do it.\tMache es!\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049386 (mailohilohi) & #899757 (Esperantostern)',
#  'Do it.\tTue es.\tCC-BY 2.0 (France) Attribution: tatoeba.org #6049386 (mailohilohi) & #6625084 (Felixjp)',
#  'Go on.\tMach weiter.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #6625701 (Felixjp)',
#  'Hello!\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #380701 (cburgmer)',
#  'Hello!\tSers!\tCC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #4690618 (tarsier)',
#  'Hello.\tHallo!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1858850 (LanguageExpert) & #380701 (cburgmer)',
#  'Hurry!\tBeeil dich!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #131 (MUIRIEL)',
#  'Hurry!\tSchnell!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1182334 (Hideousss) & #1169837 (Haehnchenpaella)',
#  'I hid.\tIch versteckte mich.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397686 (CK) & #4785329 (Tamy)',
#  'I hid.\tIch habe mich versteckt.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397686 (CK) & #8861617 (mramosch)',
#  'I ran.\tIch rannte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828607 (CK) & #6643977 (Felixjp)',
#  'I see.\tIch verstehe.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #547386 (Espi)',
#  'I see.\tAha.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #5677459 (eric2)',
#  'I try.\tIch versuche es.\tCC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #4561105 (Juri)',
#  'I try.\tIch probiere es.\tCC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #4944510 (Hans_Adler)',
#  'I won!\tIch hab gewonnen!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941621 (Hans_Adler)',
#  'I won!\tIch habe gewonnen!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #4941622 (Hans_Adler)',
#  'I won.\tIch habe gewonnen.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828608 (CK) & #3143019 (samueldora)',
#  'Oh no!\tOh, Nein!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1299275 (CK) & #4561088 (Juri)',
#  'Relax.\tEntspann dich.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #3172031 (dinkel_girl)',
#  'Shoot!\tFeuer!\tCC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #1958697 (Tamy)',
#  'Shoot!\tSchieß!\tCC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #8597807 (Roujin)',
#  'Smile.\tLächeln!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #4659632 (AC)',
#  'Sorry?\tEntschuldigung?\tCC-BY 2.0 (France) Attribution: tatoeba.org #9020701 (Rawrren) & #8752649 (skanne)',
#  'Ask me.\tFrag mich!\tCC-BY 2.0 (France) Attribution: tatoeba.org #8540654 (CK) & #8861637 (mramosch)',
#  'Ask me.\tFragt mich!\tCC-BY 2.0 (France) Attribution: tatoeba.org #8540654 (CK) & #8861639 (mramosch)',
#  'Ask me.\tFragen Sie mich!\tCC-BY 2.0 (France) Attribution: tatoeba.org #8540654 (CK) & #8861640 (mramosch)',
#  'Attack!\tAngriff!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5227364 (jaz1313)',
#  'Attack!\tAttacke!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5946689 (list)',
#  'Buy it.\tKauf’s!\tCC-BY 2.0 (France) Attribution: tatoeba.org #10016573 (ddnktr) & #10016608 (Pfirsichbaeumchen)',
#  'Cheers!\tZum Wohl!\tCC-BY 2.0 (France) Attribution: tatoeba.org #487006 (human600) & #957535 (Sudajaengi)',
#  'Eat it.\tIss es.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4768107 (garborg) & #8597873 (Roujin)',
#  'Eat up.\tIss fertig!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4769344 (garborg) & #3865600 (Giulio)',
#  'Eat up.\tIss auf.\tCC-BY 2.0 (France) Attribution: tatoeba.org #4769344 (garborg) & #8227448 (MisterTrouser)',
#  'Eat up.\tIss auf!\tCC-BY 2.0 (France) Attribution: tatoeba.org #4769344 (garborg) & #8637528 (Pfirsichbaeumchen)',
#  'Freeze!\tKeine Bewegung!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155388 (Pfirsichbaeumchen)',
#  'Freeze!\tStehenbleiben!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2160489 (Dreamk33) & #3155390 (Pfirsichbaeumchen)',
#  'Go now.\tGeh jetzt!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #1853898 (Tamy)',
#  'Got it!\tVerstanden!\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5253180 (christian42)',
#  'Got it!\tIch hab’s!\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5622418 (raggione)',
#  'Got it!\tAha!\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5622431 (list)',
#  'Got it?\tKapiert?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (CM) & #455377 (MUIRIEL)',
#  'Got it?\tVerstanden?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (CM) & #455452 (Zaghawa)',
#  'Got it?\tEinverstanden?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (CM) & #1808892 (Tamy)',
#  'He ran.\tEr rannte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401396 (Esperantostern)',
#  'He ran.\tEr lief.\tCC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1401397 (Esperantostern)',
#  'Hop in.\tMach mit!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #4659678 (AC)',
#  'Hop in.\tSpring rein!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #8876304 (Yorwba)',
#  'Hug me.\tDrück mich!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846595 (Pfirsichbaeumchen)',
#  'Hug me.\tNimm mich in den Arm!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1846597 (Pfirsichbaeumchen)',
#  'Hug me.\tUmarme mich!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #1854006 (Pfirsichbaeumchen)',
#  'I care.\tMir ist es wichtig.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397687 (CK) & #604208 (BraveSentry)',
#  'I fell.\tIch fiel.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942958 (Hans_Adler)',
#  'I fell.\tIch fiel hin.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942959 (Hans_Adler)',
#  'I fell.\tIch stürzte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942960 (Hans_Adler)',
#  'I fell.\tIch bin hingefallen.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942961 (Hans_Adler)',
#  'I fell.\tIch bin gestürzt.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #4942963 (Hans_Adler)',
#  'I fled.\tIch flüchtete.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397688 (CK) & #8861618 (mramosch)',
#  'I fled.\tIch bin geflüchtet.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397688 (CK) & #8861619 (mramosch)',
#  'I know.\tIch weiß.\tCC-BY 2.0 (France) Attribution: tatoeba.org #319990 (CK) & #358382 (MUIRIEL)',
#  'I lied.\tIch habe gelogen.\tCC-BY 2.0 (France) Attribution: tatoeba.org #3935374 (gianich73) & #3235040 (Manfredo)',
#  'I lost.\tIch habe verloren.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1755073 (Eldad) & #4659717 (AC)',
#  'I paid.\tIch habe bezahlt.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7141489 (Luiaard)',
#  'I paid.\tIch zahlte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828610 (CK) & #7141490 (Luiaard)',
#  'I pass.\tIch passe.\tCC-BY 2.0 (France) Attribution: tatoeba.org #9850637 (AlanF_US) & #11570604 (regnewrum)',
#  'I sang.\tIch sang.\tCC-BY 2.0 (France) Attribution: tatoeba.org #7290637 (shekitten) & #4781463 (Tamy)',
#  'I spit.\tIch spuckte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397689 (CK) & #8861620 (mramosch)',
#  'I spit.\tIch habe gespuckt.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397689 (CK) & #8861621 (mramosch)',
#  'I swim.\tIch schwimme.\tCC-BY 2.0 (France) Attribution: tatoeba.org #5828611 (CK) & #7091837 (Luiaard)',
#  'I wept.\tIch weinte.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397690 (CK) & #7091838 (Luiaard)',
#  'I wept.\tIch habe geweint.\tCC-BY 2.0 (France) Attribution: tatoeba.org #8397690 (CK) & #7091839 (Luiaard)',
#  "I'm 19.\tIch bin 19 Jahre alt.\tCC-BY 2.0 (France) Attribution: tatoeba.org #442400 (sacredceltic) & #345406 (MUIRIEL)",
#  "I'm 19.\tIch bin 19.\tCC-BY 2.0 (France) Attribution: tatoeba.org #442400 (sacredceltic) & #442436 (MUIRIEL)",
#  "I'm OK.\tMir geht's gut.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #341452 (MUIRIEL)",
#  "I'm OK.\tEs geht mir gut.\tCC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #2705321 (Pfirsichbaeumchen)",
#  "I'm up.\tIch bin wach.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2765357 (arnxy20) & #1313714 (Pfirsichbaeumchen)",
#  "I'm up.\tIch bin auf.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2765357 (arnxy20) & #6626001 (Felixjp)",
#  'Listen.\tHört zu.\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913088 (CK) & #8962498 (Zephyr)',
#  'No way!\tUnmöglich!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CM) & #976 (MUIRIEL)',
#  'No way!\tDas kommt nicht in Frage!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CM) & #444494 (Espi)',
#  'No way!\tDas gibt’s doch nicht!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CM) & #722128 (Pfirsichbaeumchen)',
#  'No way!\tAusgeschlossen!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CM) & #1670006 (Pfirsichbaeumchen)',
#  'No way!\tIn keinster Weise!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CM) & #2344583 (Vortarulo)']

# %% [markdown]
# ## English-German Split

# %%
first_column_pattern = r'^(.+?)\t'
for item in sample_sentences:
    print(re.search(first_column_pattern, item))
    print(re.search(first_column_pattern, item).group(1))

second_column_pattern = r'\t(.+?)\t'
for item in sample_sentences:
    print(re.search(second_column_pattern, item))
    print(re.search(second_column_pattern, item).group(1))
# Out:
# <re.Match object; span=(0, 4), match='Go.\t'>
# Go.
# <re.Match object; span=(0, 4), match='Hi.\t'>
# Hi.
# <re.Match object; span=(0, 4), match='Hi.\t'>
# Hi.
# <re.Match object; span=(0, 5), match='Run!\t'>
# Run!
# <re.Match object; span=(0, 5), match='Run.\t'>
# Run.
# <re.Match object; span=(0, 5), match='Wow!\t'>
# Wow!
# <re.Match object; span=(0, 5), match='Wow!\t'>
# Wow!
# <re.Match object; span=(0, 6), match='Duck!\t'>
# Duck!
# <re.Match object; span=(0, 6), match='Fire!\t'>
# Fire!
# <re.Match object; span=(0, 6), match='Help!\t'>
# Help!
# <re.Match object; span=(0, 6), match='Help!\t'>
# Help!
# <re.Match object; span=(0, 6), match='Stay.\t'>
# Stay.
# <re.Match object; span=(0, 6), match='Stop!\t'>
# Stop!
# <re.Match object; span=(0, 6), match='Stop!\t'>
# Stop!
# <re.Match object; span=(0, 6), match='Wait!\t'>
# Wait!
# <re.Match object; span=(0, 6), match='Wait.\t'>
# Wait.
# <re.Match object; span=(0, 7), match='Begin.\t'>
# Begin.
# <re.Match object; span=(0, 7), match='Do it.\t'>
# Do it.
# <re.Match object; span=(0, 7), match='Do it.\t'>
# Do it.
# <re.Match object; span=(0, 7), match='Go on.\t'>
# Go on.
# <re.Match object; span=(0, 7), match='Hello!\t'>
# Hello!
# <re.Match object; span=(0, 7), match='Hello!\t'>
# Hello!
# <re.Match object; span=(0, 7), match='Hello.\t'>
# Hello.
# <re.Match object; span=(0, 7), match='Hurry!\t'>
# Hurry!
# <re.Match object; span=(0, 7), match='Hurry!\t'>
# Hurry!
# <re.Match object; span=(0, 7), match='I hid.\t'>
# I hid.
# <re.Match object; span=(0, 7), match='I hid.\t'>
# I hid.
# <re.Match object; span=(0, 7), match='I ran.\t'>
# I ran.
# <re.Match object; span=(0, 7), match='I see.\t'>
# I see.
# <re.Match object; span=(0, 7), match='I see.\t'>
# I see.
# <re.Match object; span=(0, 7), match='I try.\t'>
# I try.
# <re.Match object; span=(0, 7), match='I try.\t'>
# I try.
# <re.Match object; span=(0, 7), match='I won!\t'>
# I won!
# <re.Match object; span=(0, 7), match='I won!\t'>
# I won!
# <re.Match object; span=(0, 7), match='I won.\t'>
# I won.
# <re.Match object; span=(0, 7), match='Oh no!\t'>
# Oh no!
# <re.Match object; span=(0, 7), match='Relax.\t'>
# Relax.
# <re.Match object; span=(0, 7), match='Shoot!\t'>
# Shoot!
# <re.Match object; span=(0, 7), match='Shoot!\t'>
# Shoot!
# <re.Match object; span=(0, 7), match='Smile.\t'>
# Smile.
# <re.Match object; span=(0, 7), match='Sorry?\t'>
# Sorry?
# <re.Match object; span=(0, 8), match='Ask me.\t'>
# Ask me.
# <re.Match object; span=(0, 8), match='Ask me.\t'>
# Ask me.
# <re.Match object; span=(0, 8), match='Ask me.\t'>
# Ask me.
# <re.Match object; span=(0, 8), match='Attack!\t'>
# Attack!
# <re.Match object; span=(0, 8), match='Attack!\t'>
# Attack!
# <re.Match object; span=(0, 8), match='Buy it.\t'>
# Buy it.
# <re.Match object; span=(0, 8), match='Cheers!\t'>
# Cheers!
# <re.Match object; span=(0, 8), match='Eat it.\t'>
# Eat it.
# <re.Match object; span=(0, 8), match='Eat up.\t'>
# Eat up.
# <re.Match object; span=(0, 8), match='Eat up.\t'>
# Eat up.
# <re.Match object; span=(0, 8), match='Eat up.\t'>
# Eat up.
# <re.Match object; span=(0, 8), match='Freeze!\t'>
# Freeze!
# <re.Match object; span=(0, 8), match='Freeze!\t'>
# Freeze!
# <re.Match object; span=(0, 8), match='Go now.\t'>
# Go now.
# <re.Match object; span=(0, 8), match='Got it!\t'>
# Got it!
# <re.Match object; span=(0, 8), match='Got it!\t'>
# Got it!
# <re.Match object; span=(0, 8), match='Got it!\t'>
# Got it!
# <re.Match object; span=(0, 8), match='Got it?\t'>
# Got it?
# <re.Match object; span=(0, 8), match='Got it?\t'>
# Got it?
# <re.Match object; span=(0, 8), match='Got it?\t'>
# Got it?
# <re.Match object; span=(0, 8), match='He ran.\t'>
# He ran.
# <re.Match object; span=(0, 8), match='He ran.\t'>
# He ran.
# <re.Match object; span=(0, 8), match='Hop in.\t'>
# Hop in.
# <re.Match object; span=(0, 8), match='Hop in.\t'>
# Hop in.
# <re.Match object; span=(0, 8), match='Hug me.\t'>
# Hug me.
# <re.Match object; span=(0, 8), match='Hug me.\t'>
# Hug me.
# <re.Match object; span=(0, 8), match='Hug me.\t'>
# Hug me.
# <re.Match object; span=(0, 8), match='I care.\t'>
# I care.
# <re.Match object; span=(0, 8), match='I fell.\t'>
# I fell.
# <re.Match object; span=(0, 8), match='I fell.\t'>
# I fell.
# <re.Match object; span=(0, 8), match='I fell.\t'>
# I fell.
# <re.Match object; span=(0, 8), match='I fell.\t'>
# I fell.
# <re.Match object; span=(0, 8), match='I fell.\t'>
# I fell.
# <re.Match object; span=(0, 8), match='I fled.\t'>
# I fled.
# <re.Match object; span=(0, 8), match='I fled.\t'>
# I fled.
# <re.Match object; span=(0, 8), match='I know.\t'>
# I know.
# <re.Match object; span=(0, 8), match='I lied.\t'>
# I lied.
# <re.Match object; span=(0, 8), match='I lost.\t'>
# I lost.
# <re.Match object; span=(0, 8), match='I paid.\t'>
# I paid.
# <re.Match object; span=(0, 8), match='I paid.\t'>
# I paid.
# <re.Match object; span=(0, 8), match='I pass.\t'>
# I pass.
# <re.Match object; span=(0, 8), match='I sang.\t'>
# I sang.
# <re.Match object; span=(0, 8), match='I spit.\t'>
# I spit.
# <re.Match object; span=(0, 8), match='I spit.\t'>
# I spit.
# <re.Match object; span=(0, 8), match='I swim.\t'>
# I swim.
# <re.Match object; span=(0, 8), match='I wept.\t'>
# I wept.
# <re.Match object; span=(0, 8), match='I wept.\t'>
# I wept.
# <re.Match object; span=(0, 8), match="I'm 19.\t">
# I'm 19.
# <re.Match object; span=(0, 8), match="I'm 19.\t">
# I'm 19.
# <re.Match object; span=(0, 8), match="I'm OK.\t">
# I'm OK.
# <re.Match object; span=(0, 8), match="I'm OK.\t">
# I'm OK.
# <re.Match object; span=(0, 8), match="I'm up.\t">
# I'm up.
# <re.Match object; span=(0, 8), match="I'm up.\t">
# I'm up.
# <re.Match object; span=(0, 8), match='Listen.\t'>
# Listen.
# <re.Match object; span=(0, 8), match='No way!\t'>
# No way!
# <re.Match object; span=(0, 8), match='No way!\t'>
# No way!
# <re.Match object; span=(0, 8), match='No way!\t'>
# No way!
# <re.Match object; span=(0, 8), match='No way!\t'>
# No way!
# <re.Match object; span=(0, 8), match='No way!\t'>
# No way!
# <re.Match object; span=(3, 9), match='\tGeh.\t'>
# Geh.
# <re.Match object; span=(3, 11), match='\tHallo!\t'>
# Hallo!
# <re.Match object; span=(3, 15), match='\tGrüß Gott!\t'>
# Grüß Gott!
# <re.Match object; span=(4, 11), match='\tLauf!\t'>
# Lauf!
# <re.Match object; span=(4, 11), match='\tLauf!\t'>
# Lauf!
# <re.Match object; span=(4, 17), match='\tPotzdonner!\t'>
# Potzdonner!
# <re.Match object; span=(4, 19), match='\tDonnerwetter!\t'>
# Donnerwetter!
# <re.Match object; span=(5, 19), match='\tKopf runter!\t'>
# Kopf runter!
# <re.Match object; span=(5, 13), match='\tFeuer!\t'>
# Feuer!
# <re.Match object; span=(5, 13), match='\tHilfe!\t'>
# Hilfe!
# <re.Match object; span=(5, 15), match='\tZu Hülf!\t'>
# Zu Hülf!
# <re.Match object; span=(5, 13), match='\tBleib!\t'>
# Bleib!
# <re.Match object; span=(5, 13), match='\tStopp!\t'>
# Stopp!
# <re.Match object; span=(5, 16), match='\tAnhalten!\t'>
# Anhalten!
# <re.Match object; span=(5, 13), match='\tWarte!\t'>
# Warte!
# <re.Match object; span=(5, 13), match='\tWarte.\t'>
# Warte.
# <re.Match object; span=(6, 16), match='\tFang an.\t'>
# Fang an.
# <re.Match object; span=(6, 17), match='\tMache es!\t'>
# Mache es!
# <re.Match object; span=(6, 15), match='\tTue es.\t'>
# Tue es.
# <re.Match object; span=(6, 20), match='\tMach weiter.\t'>
# Mach weiter.
# <re.Match object; span=(6, 14), match='\tHallo!\t'>
# Hallo!
# <re.Match object; span=(6, 13), match='\tSers!\t'>
# Sers!
# <re.Match object; span=(6, 14), match='\tHallo!\t'>
# Hallo!
# <re.Match object; span=(6, 19), match='\tBeeil dich!\t'>
# Beeil dich!
# <re.Match object; span=(6, 16), match='\tSchnell!\t'>
# Schnell!
# <re.Match object; span=(6, 28), match='\tIch versteckte mich.\t'>
# Ich versteckte mich.
# <re.Match object; span=(6, 32), match='\tIch habe mich versteckt.\t'>
# Ich habe mich versteckt.
# <re.Match object; span=(6, 19), match='\tIch rannte.\t'>
# Ich rannte.
# <re.Match object; span=(6, 21), match='\tIch verstehe.\t'>
# Ich verstehe.
# <re.Match object; span=(6, 12), match='\tAha.\t'>
# Aha.
# <re.Match object; span=(6, 24), match='\tIch versuche es.\t'>
# Ich versuche es.
# <re.Match object; span=(6, 24), match='\tIch probiere es.\t'>
# Ich probiere es.
# <re.Match object; span=(6, 25), match='\tIch hab gewonnen!\t'>
# Ich hab gewonnen!
# <re.Match object; span=(6, 26), match='\tIch habe gewonnen!\t'>
# Ich habe gewonnen!
# <re.Match object; span=(6, 26), match='\tIch habe gewonnen.\t'>
# Ich habe gewonnen.
# <re.Match object; span=(6, 17), match='\tOh, Nein!\t'>
# Oh, Nein!
# <re.Match object; span=(6, 22), match='\tEntspann dich.\t'>
# Entspann dich.
# <re.Match object; span=(6, 14), match='\tFeuer!\t'>
# Feuer!
# <re.Match object; span=(6, 15), match='\tSchieß!\t'>
# Schieß!
# <re.Match object; span=(6, 16), match='\tLächeln!\t'>
# Lächeln!
# <re.Match object; span=(6, 23), match='\tEntschuldigung?\t'>
# Entschuldigung?
# <re.Match object; span=(7, 19), match='\tFrag mich!\t'>
# Frag mich!
# <re.Match object; span=(7, 20), match='\tFragt mich!\t'>
# Fragt mich!
# <re.Match object; span=(7, 25), match='\tFragen Sie mich!\t'>
# Fragen Sie mich!
# <re.Match object; span=(7, 17), match='\tAngriff!\t'>
# Angriff!
# <re.Match object; span=(7, 17), match='\tAttacke!\t'>
# Attacke!
# <re.Match object; span=(7, 16), match='\tKauf’s!\t'>
# Kauf’s!
# <re.Match object; span=(7, 18), match='\tZum Wohl!\t'>
# Zum Wohl!
# <re.Match object; span=(7, 16), match='\tIss es.\t'>
# Iss es.
# <re.Match object; span=(7, 20), match='\tIss fertig!\t'>
# Iss fertig!
# <re.Match object; span=(7, 17), match='\tIss auf.\t'>
# Iss auf.
# <re.Match object; span=(7, 17), match='\tIss auf!\t'>
# Iss auf!
# <re.Match object; span=(7, 24), match='\tKeine Bewegung!\t'>
# Keine Bewegung!
# <re.Match object; span=(7, 23), match='\tStehenbleiben!\t'>
# Stehenbleiben!
# <re.Match object; span=(7, 19), match='\tGeh jetzt!\t'>
# Geh jetzt!
# <re.Match object; span=(7, 20), match='\tVerstanden!\t'>
# Verstanden!
# <re.Match object; span=(7, 19), match='\tIch hab’s!\t'>
# Ich hab’s!
# <re.Match object; span=(7, 13), match='\tAha!\t'>
# Aha!
# <re.Match object; span=(7, 17), match='\tKapiert?\t'>
# Kapiert?
# <re.Match object; span=(7, 20), match='\tVerstanden?\t'>
# Verstanden?
# <re.Match object; span=(7, 23), match='\tEinverstanden?\t'>
# Einverstanden?
# <re.Match object; span=(7, 19), match='\tEr rannte.\t'>
# Er rannte.
# <re.Match object; span=(7, 17), match='\tEr lief.\t'>
# Er lief.
# <re.Match object; span=(7, 18), match='\tMach mit!\t'>
# Mach mit!
# <re.Match object; span=(7, 21), match='\tSpring rein!\t'>
# Spring rein!
# <re.Match object; span=(7, 20), match='\tDrück mich!\t'>
# Drück mich!
# <re.Match object; span=(7, 30), match='\tNimm mich in den Arm!\t'>
# Nimm mich in den Arm!
# <re.Match object; span=(7, 21), match='\tUmarme mich!\t'>
# Umarme mich!
# <re.Match object; span=(7, 28), match='\tMir ist es wichtig.\t'>
# Mir ist es wichtig.
# <re.Match object; span=(7, 18), match='\tIch fiel.\t'>
# Ich fiel.
# <re.Match object; span=(7, 22), match='\tIch fiel hin.\t'>
# Ich fiel hin.
# <re.Match object; span=(7, 21), match='\tIch stürzte.\t'>
# Ich stürzte.
# <re.Match object; span=(7, 29), match='\tIch bin hingefallen.\t'>
# Ich bin hingefallen.
# <re.Match object; span=(7, 26), match='\tIch bin gestürzt.\t'>
# Ich bin gestürzt.
# <re.Match object; span=(7, 23), match='\tIch flüchtete.\t'>
# Ich flüchtete.
# <re.Match object; span=(7, 28), match='\tIch bin geflüchtet.\t'>
# Ich bin geflüchtet.
# <re.Match object; span=(7, 18), match='\tIch weiß.\t'>
# Ich weiß.
# <re.Match object; span=(7, 26), match='\tIch habe gelogen.\t'>
# Ich habe gelogen.
# <re.Match object; span=(7, 27), match='\tIch habe verloren.\t'>
# Ich habe verloren.
# <re.Match object; span=(7, 26), match='\tIch habe bezahlt.\t'>
# Ich habe bezahlt.
# <re.Match object; span=(7, 20), match='\tIch zahlte.\t'>
# Ich zahlte.
# <re.Match object; span=(7, 19), match='\tIch passe.\t'>
# Ich passe.
# <re.Match object; span=(7, 18), match='\tIch sang.\t'>
# Ich sang.
# <re.Match object; span=(7, 21), match='\tIch spuckte.\t'>
# Ich spuckte.
# <re.Match object; span=(7, 27), match='\tIch habe gespuckt.\t'>
# Ich habe gespuckt.
# <re.Match object; span=(7, 22), match='\tIch schwimme.\t'>
# Ich schwimme.
# <re.Match object; span=(7, 20), match='\tIch weinte.\t'>
# Ich weinte.
# <re.Match object; span=(7, 26), match='\tIch habe geweint.\t'>
# Ich habe geweint.
# <re.Match object; span=(7, 30), match='\tIch bin 19 Jahre alt.\t'>
# Ich bin 19 Jahre alt.
# <re.Match object; span=(7, 20), match='\tIch bin 19.\t'>
# Ich bin 19.
# <re.Match object; span=(7, 24), match="\tMir geht's gut.\t">
# Mir geht's gut.
# <re.Match object; span=(7, 25), match='\tEs geht mir gut.\t'>
# Es geht mir gut.
# <re.Match object; span=(7, 22), match='\tIch bin wach.\t'>
# Ich bin wach.
# <re.Match object; span=(7, 21), match='\tIch bin auf.\t'>
# Ich bin auf.
# <re.Match object; span=(7, 17), match='\tHört zu.\t'>
# Hört zu.
# <re.Match object; span=(7, 19), match='\tUnmöglich!\t'>
# Unmöglich!
# <re.Match object; span=(7, 34), match='\tDas kommt nicht in Frage!\t'>
# Das kommt nicht in Frage!
# <re.Match object; span=(7, 31), match='\tDas gibt’s doch nicht!\t'>
# Das gibt’s doch nicht!
# <re.Match object; span=(7, 24), match='\tAusgeschlossen!\t'>
# Ausgeschlossen!
# <re.Match object; span=(7, 27), match='\tIn keinster Weise!\t'>
# In keinster Weise!

# %%
first_column_pattern = r'^(.+?)\t'
first_column = [re.search(first_column_pattern, item).group(1) if re.search(first_column_pattern, item) else 'no match' for item in sample_sentences]
first_column
# Out:
# Out[127]: ['Go.',
#  'Hi.',
#  'Hi.',
#  'Run!',
#  'Run.',
#  'Wow!',
#  'Wow!',
#  'Duck!',
#  'Fire!',
#  'Help!',
#  'Help!',
#  'Stay.',
#  'Stop!',
#  'Stop!',
#  'Wait!',
#  'Wait.',
#  'Begin.',
#  'Do it.',
#  'Do it.',
#  'Go on.',
#  'Hello!',
#  'Hello!',
#  'Hello.',
#  'Hurry!',
#  'Hurry!',
#  'I hid.',
#  'I hid.',
#  'I ran.',
#  'I see.',
#  'I see.',
#  'I try.',
#  'I try.',
#  'I won!',
#  'I won!',
#  'I won.',
#  'Oh no!',
#  'Relax.',
#  'Shoot!',
#  'Shoot!',
#  'Smile.',
#  'Sorry?',
#  'Ask me.',
#  'Ask me.',
#  'Ask me.',
#  'Attack!',
#  'Attack!',
#  'Buy it.',
#  'Cheers!',
#  'Eat it.',
#  'Eat up.',
#  'Eat up.',
#  'Eat up.',
#  'Freeze!',
#  'Freeze!',
#  'Go now.',
#  'Got it!',
#  'Got it!',
#  'Got it!',
#  'Got it?',
#  'Got it?',
#  'Got it?',
#  'He ran.',
#  'He ran.',
#  'Hop in.',
#  'Hop in.',
#  'Hug me.',
#  'Hug me.',
#  'Hug me.',
#  'I care.',
#  'I fell.',
#  'I fell.',
#  'I fell.',
#  'I fell.',
#  'I fell.',
#  'I fled.',
#  'I fled.',
#  'I know.',
#  'I lied.',
#  'I lost.',
#  'I paid.',
#  'I paid.',
#  'I pass.',
#  'I sang.',
#  'I spit.',
#  'I spit.',
#  'I swim.',
#  'I wept.',
#  'I wept.',
#  "I'm 19.",
#  "I'm 19.",
#  "I'm OK.",
#  "I'm OK.",
#  "I'm up.",
#  "I'm up.",
#  'Listen.',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!',
#  'No way!']

# %%
second_column_pattern = r'\t(.+?)\t'
second_column = [re.search(second_column_pattern, item).group(1) if re.search(second_column_pattern, item) else 'no match' for item in sample_sentences]
second_column
# Out:
# Out[128]: ['Geh.',
#  'Hallo!',
#  'Grüß Gott!',
#  'Lauf!',
#  'Lauf!',
#  'Potzdonner!',
#  'Donnerwetter!',
#  'Kopf runter!',
#  'Feuer!',
#  'Hilfe!',
#  'Zu Hülf!',
#  'Bleib!',
#  'Stopp!',
#  'Anhalten!',
#  'Warte!',
#  'Warte.',
#  'Fang an.',
#  'Mache es!',
#  'Tue es.',
#  'Mach weiter.',
#  'Hallo!',
#  'Sers!',
#  'Hallo!',
#  'Beeil dich!',
#  'Schnell!',
#  'Ich versteckte mich.',
#  'Ich habe mich versteckt.',
#  'Ich rannte.',
#  'Ich verstehe.',
#  'Aha.',
#  'Ich versuche es.',
#  'Ich probiere es.',
#  'Ich hab gewonnen!',
#  'Ich habe gewonnen!',
#  'Ich habe gewonnen.',
#  'Oh, Nein!',
#  'Entspann dich.',
#  'Feuer!',
#  'Schieß!',
#  'Lächeln!',
#  'Entschuldigung?',
#  'Frag mich!',
#  'Fragt mich!',
#  'Fragen Sie mich!',
#  'Angriff!',
#  'Attacke!',
#  'Kauf’s!',
#  'Zum Wohl!',
#  'Iss es.',
#  'Iss fertig!',
#  'Iss auf.',
#  'Iss auf!',
#  'Keine Bewegung!',
#  'Stehenbleiben!',
#  'Geh jetzt!',
#  'Verstanden!',
#  'Ich hab’s!',
#  'Aha!',
#  'Kapiert?',
#  'Verstanden?',
#  'Einverstanden?',
#  'Er rannte.',
#  'Er lief.',
#  'Mach mit!',
#  'Spring rein!',
#  'Drück mich!',
#  'Nimm mich in den Arm!',
#  'Umarme mich!',
#  'Mir ist es wichtig.',
#  'Ich fiel.',
#  'Ich fiel hin.',
#  'Ich stürzte.',
#  'Ich bin hingefallen.',
#  'Ich bin gestürzt.',
#  'Ich flüchtete.',
#  'Ich bin geflüchtet.',
#  'Ich weiß.',
#  'Ich habe gelogen.',
#  'Ich habe verloren.',
#  'Ich habe bezahlt.',
#  'Ich zahlte.',
#  'Ich passe.',
#  'Ich sang.',
#  'Ich spuckte.',
#  'Ich habe gespuckt.',
#  'Ich schwimme.',
#  'Ich weinte.',
#  'Ich habe geweint.',
#  'Ich bin 19 Jahre alt.',
#  'Ich bin 19.',
#  "Mir geht's gut.",
#  'Es geht mir gut.',
#  'Ich bin wach.',
#  'Ich bin auf.',
#  'Hört zu.',
#  'Unmöglich!',
#  'Das kommt nicht in Frage!',
#  'Das gibt’s doch nicht!',
#  'Ausgeschlossen!',
#  'In keinster Weise!']

# %%
df_pair = df.select(regexp_extract('value', first_column_pattern, 1).alias('English'), 
                    regexp_extract('value', second_column_pattern, 1).alias('German'), )
df_pair.show(10, truncate=False)
# Out:
# +-------+-------------+
# |English|German       |
# +-------+-------------+
# |Go.    |Geh.         |
# |Hi.    |Hallo!       |
# |Hi.    |Grüß Gott!   |
# |Run!   |Lauf!        |
# |Run.   |Lauf!        |
# |Wow!   |Potzdonner!  |
# |Wow!   |Donnerwetter!|
# |Duck!  |Kopf runter! |
# |Fire!  |Feuer!       |
# |Help!  |Hilfe!       |
# +-------+-------------+
# only showing top 10 rows

# %% [markdown]
# ## Lowercase

# %%
column_name = 'English'
df_2 = df_pair.withColumn(column_name, lower(F.col(column_name)))
column_name = 'German'
df_2 = df_2.withColumn(column_name, lower(F.col(column_name)))
df_2.show(10, truncate=False)
# Out:
# +-------+-------------+
# |English|German       |
# +-------+-------------+
# |go.    |geh.         |
# |hi.    |hallo!       |
# |hi.    |grüß gott!   |
# |run!   |lauf!        |
# |run.   |lauf!        |
# |wow!   |potzdonner!  |
# |wow!   |donnerwetter!|
# |duck!  |kopf runter! |
# |fire!  |feuer!       |
# |help!  |hilfe!       |
# +-------+-------------+
# only showing top 10 rows

# %%
df_2 = df_pair.select(
    [F.regexp_replace(F.col(column_name), r',|\.|&|\\|\||-|_|!', '').alias(column_name)
    for column_name in df_pair.columns]
    )
df_2.show(10)
# Out:
# +-------+------------+
# |English|      German|
# +-------+------------+
# |     Go|         Geh|
# |     Hi|       Hallo|
# |     Hi|   Grüß Gott|
# |    Run|        Lauf|
# |    Run|        Lauf|
# |    Wow|  Potzdonner|
# |    Wow|Donnerwetter|
# |   Duck| Kopf runter|
# |   Fire|       Feuer|
# |   Help|       Hilfe|
# +-------+------------+
# only showing top 10 rows

# %% [markdown]
# ## Removed non-printable chars

# %%
# re_print = re.compile('[^%s]' % re.escape(string.printable))
non_printable = r'[^%s]' % re.escape(string.printable)
# non_printable = r'[\.\!]'
# non_printable = r',|\.|&|\\|\||-|_|!'
print(non_printable)
df_2 = df_pair.select(
    [F.regexp_replace(F.col(column_name), non_printable, '').alias(column_name)
    for column_name in df_pair.columns]
    )
df_2.show(10)
# Out:
# [^0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"\#\$%\&'\(\)\*\+,\-\./:;<=>\?@\[\\\]\^_`\{\|\}\~\ \	\
# \\]
# +-------+-------------+
# |English|       German|
# +-------+-------------+
# |    Go.|         Geh.|
# |    Hi.|       Hallo!|
# |    Hi.|     Gr Gott!|
# |   Run!|        Lauf!|
# |   Run.|        Lauf!|
# |   Wow!|  Potzdonner!|
# |   Wow!|Donnerwetter!|
# |  Duck!| Kopf runter!|
# |  Fire!|       Feuer!|
# |  Help!|       Hilfe!|
# +-------+-------------+
# only showing top 10 rows

# %% [markdown]
# ## Remove puncuations

# %%
# re_print = re.compile('[^%s]' % re.escape(string.printable))
punctuations = r'[%s]' % re.escape(string.punctuation)
# non_printable = r'[\.\!]'
# non_printable = r',|\.|&|\\|\||-|_|!'
print(non_printable)
df_2 = df_pair.select(
    [F.regexp_replace(F.col(column_name), punctuations, '').alias(column_name)
    for column_name in df_pair.columns]
    )
df_2.show(10)
# Out:
# [^0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"\#\$%\&'\(\)\*\+,\-\./:;<=>\?@\[\\\]\^_`\{\|\}\~\ \	\
# \\]
# +-------+------------+
# |English|      German|
# +-------+------------+
# |     Go|         Geh|
# |     Hi|       Hallo|
# |     Hi|   Grüß Gott|
# |    Run|        Lauf|
# |    Run|        Lauf|
# |    Wow|  Potzdonner|
# |    Wow|Donnerwetter|
# |   Duck| Kopf runter|
# |   Fire|       Feuer|
# |   Help|       Hilfe|
# +-------+------------+
# only showing top 10 rows

# %% [markdown]
# ## Encode and then Decode

# %%
df_2 = df_pair.withColumn('German', decode(col('German'), 'UTF-8').cast('string'))
df_2.show(10, truncate=False)
# Out:
# +-------+-------------+
# |English|German       |
# +-------+-------------+
# |Go.    |Geh.         |
# |Hi.    |Hallo!       |
# |Hi.    |Grüß Gott!   |
# |Run!   |Lauf!        |
# |Run.   |Lauf!        |
# |Wow!   |Potzdonner!  |
# |Wow!   |Donnerwetter!|
# |Duck!  |Kopf runter! |
# |Fire!  |Feuer!       |
# |Help!  |Hilfe!       |
# +-------+-------------+
# only showing top 10 rows

# %% [markdown]
# ##User Defined Function (UDF)
#
# UDFs are black boxed to PySpark. Therefore, cannot apply some optimizations that PySpark does on dataframes or datasets. It is better to use Spark SQL built-in functions.

# %%
def clean_sentence(sentence):
    # To remove non-printable chars
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    # To remove punctuation chars 
    table = str.maketrans('', '', string.punctuation)
    # 
    #
    cleaned_sentence = normalize('NFD', sentence).encode('ascii', 'ignore')
    cleaned_sentence = cleaned_sentence.decode('UTF-8')
    cleaned_sentence = cleaned_sentence.split()
    cleaned_sentence = [word.lower() for word in cleaned_sentence]
    #Remove punctuation chars 
    cleaned_sentence = [word.translate(table) for word in cleaned_sentence]
    # Remove non-printable chars
    cleaned_sentence = [re_print.sub('', word) for word in cleaned_sentence]
    # Remove words with numbers? how to deal with numbers? 
    # How to deal with upper case? And , . ? % these signs? 
    cleaned_sentence = [word for word in cleaned_sentence if word.isalpha()] 
    cleaned_sentence = ' '.join(cleaned_sentence)
    #
    #
    return cleaned_sentence


my_udf = udf(lambda x:clean_sentence(x), StringType())
df_pair.select(df_pair.German, my_udf(df_pair.German).alias('German')).show(10)
df_pair.select(df_pair.English, my_udf(df_pair.English).alias('English')).show(10)
# Out:
# +-------------+------------+
# |       German|      German|
# +-------------+------------+
# |         Geh.|         geh|
# |       Hallo!|       hallo|
# |   Grüß Gott!|    gru gott|
# |        Lauf!|        lauf|
# |        Lauf!|        lauf|
# |  Potzdonner!|  potzdonner|
# |Donnerwetter!|donnerwetter|
# | Kopf runter!| kopf runter|
# |       Feuer!|       feuer|
# |       Hilfe!|       hilfe|
# +-------------+------------+
# only showing top 10 rows
#
# +-------+-------+
# |English|English|
# +-------+-------+
# |    Go.|     go|
# |    Hi.|     hi|
# |    Hi.|     hi|
# |   Run!|    run|
# |   Run.|    run|
# |   Wow!|    wow|
# |   Wow!|    wow|
# |  Duck!|   duck|
# |  Fire!|   fire|
# |  Help!|   help|
# +-------+-------+
# only showing top 10 rows

# %%
df_cleaned = df_pair.withColumn('German', my_udf(df_pair.German).alias('German'))
df_cleaned = df_cleaned.withColumn('English', my_udf(df_pair.English).alias('English'))  
df_cleaned.show(20, truncate=False)
# Out:
# +-------+------------+
# |English|German      |
# +-------+------------+
# |go     |geh         |
# |hi     |hallo       |
# |hi     |gru gott    |
# |run    |lauf        |
# |run    |lauf        |
# |wow    |potzdonner  |
# |wow    |donnerwetter|
# |duck   |kopf runter |
# |fire   |feuer       |
# |help   |hilfe       |
# |help   |zu hulf     |
# |stay   |bleib       |
# |stop   |stopp       |
# |stop   |anhalten    |
# |wait   |warte       |
# |wait   |warte       |
# |begin  |fang an     |
# |do it  |mache es    |
# |do it  |tue es      |
# |go on  |mach weiter |
# +-------+------------+
# only showing top 20 rows

# %%
df_cleaned.count()
# Out:
# Out[137]: 261499

# %% [markdown]
# #Save the data

# %%
# %fs ls /FileStore/tables/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Bookings.csv</td><td>Bookings.csv</td><td>170118</td><td>1674344235000</td></tr><tr><td>dbfs:/FileStore/tables/English-German.csv/</td><td>English-German.csv/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Facilities.csv</td><td>Facilities.csv</td><td>494</td><td>1674344235000</td></tr><tr><td>dbfs:/FileStore/tables/Members.csv</td><td>Members.csv</td><td>3313</td><td>1674344236000</td></tr><tr><td>dbfs:/FileStore/tables/NASA_access_log_Aug95.txt</td><td>NASA_access_log_Aug95.txt</td><td>167813770</td><td>1675580793000</td></tr><tr><td>dbfs:/FileStore/tables/NASA_access_log_Jul95.txt</td><td>NASA_access_log_Jul95.txt</td><td>205242368</td><td>1675580851000</td></tr><tr><td>dbfs:/FileStore/tables/deu.txt</td><td>deu.txt</td><td>40721427</td><td>1687189983000</td></tr></tbody></table></div>

# %%
#%fs rm -r /FileStore/tables/English-German.csv

# %% [markdown]
# ## CSV file

# %%
df_cleaned.coalesce(1).write.format('com.databricks.spark.csv').option('header', 'true').save('dbfs:/FileStore/tables/English-German.csv')

# %% [markdown]
# ## Pickle file - Does not work

# %%
# filename = '/dbfs/FileStore/tables/english-german.pkl'
# with open(filename, 'wb') as f:
#     dump(df_cleaned, f)
